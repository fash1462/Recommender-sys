# %%
#Preprocessing data to get the most popular movies for a test user
# import libraries 

import pandas as pd
import numpy as np
import time

# %%
movies = pd.read_csv('datasets/movies_metadata.csv')
# Out:
# C:\Users\FATIMA\AppData\Local\Temp\ipykernel_5976\3612041176.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('datasets/movies_metadata.csv')

# %%
movies.shape
# Out:
# (45466, 24)

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
# recommendation will be based on these features only
movies = movies.loc[:,['id','imdb_id','title','poster_path','vote_average','vote_count','release_date']]

# %%
movies_sorted = movies.sort_values(by = 'vote_count',ascending=False)

# %%
movies_sorted
# Out:
#       id    imdb_id                        title  \
# 0    862  tt0114709                    Toy Story
# 1   8844  tt0113497                      Jumanji
# 5    949  tt0113277                         Heat
# 9    710  tt0113189                    GoldenEye
# 8   9091  tt0114576                 Sudden Death
# 4  11862  tt0113041  Father of the Bride Part II
# 6  11860  tt0114319                      Sabrina
# 2  15602  tt0113228             Grumpier Old Men
# 7  45325  tt0112302                 Tom and Huck
# 3  31357  tt0114885            Waiting to Exhale
#
#                         poster_path  vote_average  vote_count
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg           7.7      5415.0
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg           6.9      2413.0
# 5  /zMyfPUelumio3tiDKPffaUpsQTD.jpg           7.7      1886.0
# 9  /5c0ovjT41KnYIHYuF4AWsTe3sKh.jpg           6.6      1194.0
# 8  /eoWvKD60lT95Ss1MYNgVExpo5iU.jpg           5.5       174.0
# ...

# %%
movies_sorted.to_csv('popularity.csv')

# %%
movies
# Out:
#            id    imdb_id                        title  \
# 0         862  tt0114709                    Toy Story
# 1        8844  tt0113497                      Jumanji
# 2       15602  tt0113228             Grumpier Old Men
# 3       31357  tt0114885            Waiting to Exhale
# 4       11862  tt0113041  Father of the Bride Part II
# ...       ...        ...                          ...
# 45461  439050  tt6209470                       Subdue
# 45462  111109  tt2028550          Century of Birthing
# 45463   67758  tt0303758                     Betrayal
# 45464  227506  tt0008536             Satan Triumphant
# 45465  461257  tt6980792                     Queerama
#
#                             poster_path  vote_average  vote_count release_date
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg           7.7      5415.0   1995-10-30
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg           6.9      2413.0   1995-12-15
# ...

# %%
print(type(movies.release_date[0]))
# Out:
# <class 'str'>

# %%
latest = movies.sort_values('release_date',ascending = False)

# %%
latest_df = latest[0:10]

# %%
latest_df
# Out:
#                id    imdb_id                            title  \
# 35587  2014-01-01          0                              NaN
# 26559       76600  tt1630029                         Avatar 2
# 38885      299782  tt0069049       The Other Side of the Wind
# 30402       38700  tt1502397                Bad Boys for Life
# 38130      332283  tt3906082                     Mary Shelley
# 44535      412059  tt5613402                     Mobile Homes
# 33359      302349  tt3038708        Iron Sky: The Coming Race
# 33358      252983  tt3498786                       Sly Cooper
# 30536      245842  tt2328678              The King's Daughter
# 44301      341689  tt3859310  How to Talk to Girls at Parties
#
#                             poster_path  vote_average  vote_count release_date
# 35587                  Avalanche Sharks           NaN         NaN           22
# 26559  /wvpOVl37PR21mENpmZKVwrLUsRD.jpg           0.0        58.0   2020-12-16
# ...
